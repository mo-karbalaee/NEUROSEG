# %%
# %load_ext autoreload
# %autoreload 2

from src.models.calcium_recording import CalciumRecording
from src.segmenter import Segmenter

recording: CalciumRecording = CalciumRecording(path="../data/6s.tif")

masks, flows = Segmenter.generate_mask(recording)

recording.visualize(masks, flows)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       7 recording: CalciumRecording = CalciumRecording(path="../data/6s.tif")
#       8
#       9 masks, flows = Segmenter.generate_mask(recording)
#      10
# ---> 11 recording.visualize(masks, flows)
#
# File <string>:5, in visualize(self, masks, flows)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Documents/GitHub/NEUROSEG/.venv/lib/python3.14/site-packages/cellpose/plot.py:98, in show_segmentation(fig, img, maski, flowi, channels, file_name)
#      95 ax.axis("off")
#      97 ax = fig.add_subplot(1, 4, 4)
# ---> 98 ax.imshow(flowi)
#      99 ax.set_title("predicted cell pose")
#     100 ax.axis("off")
#
# ...

# %% [markdown]
# Cellpose seems to be incapable of segmenting my desired image, hence, fine-tuning is needed.
