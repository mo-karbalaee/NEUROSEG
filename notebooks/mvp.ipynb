# %% [markdown]
# # NEUROSEG MVP
#
# This notebook is the playground that I use to document and debug my implementation process for the MVP phase of the project.
# The rule is to only import code from other files. This helps with the goal of making an end-to-end pipeline. That is that by creating modular, reusable
# code blocks in different files, I can use the both here and in the actual main Python file in the end.
# Another important use case of this notebook is my own clarity of mind and clean processes. I can know which section is which and I can document what I did using
# markdown blocks. This is something that I can't do on Python file.
#
# With all that said, I wish you luck and let's go!

# %%
from src.test import addition

# %%
print(addition(10, 20))
# Out:
# 30
