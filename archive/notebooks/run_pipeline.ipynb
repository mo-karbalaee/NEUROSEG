# %% [markdown]
# # NEUROSEG Pipeline
# Installs the package from GitHub and runs the segmentation pipeline.

# %%
# %pip install git+https://github.com/mo-karbalaee/NEUROSEG.git@feature/add-langgraph

# %%
from pathlib import Path
from neuroseg import run, Mode

# %%
data_dir = "../data/"

# %%
run(data_dir)
