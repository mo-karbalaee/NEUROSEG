# %% [markdown]
# # Cellpose baseline metrics (GPU)
# Compute the **Cellpose baseline** Dice + instance detection-F1 on Neurofinder `00.00`,
# using the same metrics as our models. Cellpose is run on a time-projection (all neurons
# visible) and scored against the ground-truth footprints.
#
# Attach the labeled dataset (`neuroseg-labeled`), enable **GPU**, run all cells.

# %%
# %cd /kaggle/working
# !rm -rf NEUROSEG
# !git clone --depth 1 https://github.com/mo-karbalaee/NEUROSEG.git
# %cd NEUROSEG
# !pip install -e . >/dev/null
# !pip install -q cellpose

# %%
# Point --data at neurofinder.00.00 (adjust the path if the mount differs).
# !python scripts/cellpose_baseline.py \
    --data /kaggle/input/datasets/mokarbalaee/neuroseg-labeled/neurofinder.00.00/neurofinder.00.00 \
    --gpu
